# %%
# Analise de Dados:
#somar as colunas:

# %%
import pandas as pd

# %%
df = pd.read_csv('resultadoevasao.csv', sep=";")

# %%
#exibir a tabela de forma mais organizada
display(df)
# Out:
#         cod_coordenacao_regional           coordenacao_regional  cod_escola  \
# 0                             14              CRE - Santa Maria         191
# 1                              8       CRE - Núcleo Bandeirante          67
# 2                              7                    CRE - Guará          64
# 3                              3  CRE - Plano Piloto e Cruzeiro         269
# 4                             16         CRE - Recanto das Emas         144
# ...                          ...                            ...         ...
# 531749                        12                CRE - Samambaia         586
# 531750                        16         CRE - Recanto das Emas         588
# 531751                        16         CRE - Recanto das Emas         588
# 531752                        16         CRE - Recanto das Emas         588
# 531753                         7                    CRE - Guará         605
#
# ...

# %%
#df.describe()

# %% [markdown]
# # Passo 2 - Analisar a base de dados
# Temos o codigo da escola, nome da escola, curso, turma, situacao....

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 531754 entries, 0 to 531753
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   cod_coordenacao_regional  531754 non-null  int64
#  1   coordenacao_regional      531754 non-null  object
#  2   cod_escola                531754 non-null  int64
#  3   escola                    531754 non-null  object
#  4   cod_curso                 531754 non-null  int64
#  5   curso                     531754 non-null  object
#  6   cod_serie                 531754 non-null  int64
#  7   serie                     531754 non-null  object
#  8   cod_turno                 531754 non-null  int64
#  9   turno                     531754 non-null  object
#  10  cod_turma                 492405 non-null  float64
#  11  turma                     492405 non-null  object
#  12  cod_aluno                 531754 non-null  object
# ...

# %%
df2=df['curso']

# %% [markdown]
# # Qual a situação dos alunos?
# ### Quantos foram aprovados?
# ### Quantos foram transferidos?
# ### Quantos foram reprovados?
# ### Quantos deram abandono?

# %%
df['situacao'].value_counts()
# Out:
# aprovado                         332427
# transferido                      102800
# reprovado                         44605
# aprovado, com dependência         23652
# em andamento                      10556
# matrícula inativada                9821
# abandono                           5427
# em processo                        1657
# em andamento, com dependência       437
# avanço de estudos                   269
# temporalidade                       102
# Name: situacao, dtype: int64

# %%
qtde_matriculas =
