# %% [markdown]
# <a href="https://colab.research.google.com/github/profdeborapaulo/data-science-introducao/blob/main/data-science-aula01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análise Exploratória de Dados - Dados Alunos

# %% [markdown]
# ### Estes dados referem-se a um questionário socio-econômico aplicado a 50 alunos.
# * Após analisar todo o dataframe, você deverá emitir um parecer, um relatório sobre o que os dados do dataframe representam. Use como base a análise realizada em sala de aula.
# Faça um relatório demonstrando seus resultados com os números, gráficos.

# %% [markdown]
# 1.   Importando as Bibliotecas necessárias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 2.   Carregar a base de dados a ser analisada:

# %%
df = pd.read_csv("/content/drive/MyDrive/data1.csv", sep=';')

# %%
#Acessar o arquivo para dar início a análise:
df.head()
# Out:
#    Id Turma Sexo  Idade   Alt  Peso  Filhos Fuma Toler  Exerc  Cine OpCine  \
# 0   1     A    F     17  1.60  60.5       2  NAO     P      0     1      B
# 1   2     A    F     18  1.69  55.0       1  NAO     M      0     1      B
# 2   3     A    M     18  1.85  72.8       2  NAO     P      5     2      M
# 3   4     A    M     25  1.85  80.9       2  NAO     P      5     2      B
# 4   5     A    F     19  1.58  55.0       1  NAO     M      2     2      B
#
#    TV OpTV
# 0  16    R
# 1   7    R
# 2  15    R
# 3  20    R
# 4   5    R

# %%
#Acessando informações do dataframe:
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Id      50 non-null     int64
#  1   Turma   50 non-null     object
#  2   Sexo    50 non-null     object
#  3   Idade   50 non-null     int64
#  4   Alt     50 non-null     float64
#  5   Peso    50 non-null     float64
#  6   Filhos  50 non-null     int64
#  7   Fuma    50 non-null     object
#  8   Toler   50 non-null     object
#  9   Exerc   50 non-null     int64
#  10  Cine    50 non-null     int64
#  11  OpCine  50 non-null     object
#  12  TV      50 non-null     int64
#  13  OpTV    50 non-null     object
# dtypes: float64(2), int64(6), object(6)
# memory usage: 5.6+ KB

# %%
df.describe()
# Out:
#              Id      Idade        Alt       Peso     Filhos      Exerc  \
# count  50.00000  50.000000  50.000000  50.000000  50.000000  50.000000
# mean   25.50000  18.900000   1.672000  60.928000   1.700000   3.800000
# std    14.57738   2.032893   0.090599  12.179089   1.092647   2.770103
# min     1.00000  17.000000   1.450000  44.000000   1.000000   0.000000
# 25%    13.25000  18.000000   1.602500  52.125000   1.000000   2.000000
# 50%    25.50000  18.000000   1.665000  58.000000   1.000000   3.500000
# 75%    37.75000  19.000000   1.717500  67.875000   2.000000   5.750000
# max    50.00000  25.000000   1.850000  95.000000   7.000000  10.000000
#
#             Cine         TV
# count  50.000000  50.000000
# mean    1.740000  10.780000
# std     1.084398   6.890662
# min     0.000000   0.000000
# 25%     1.000000   5.000000
# 50%     2.000000  10.000000
# 75%     2.000000  14.000000
# max     5.000000  30.000000

# %% [markdown]
# # Calculando as medidas descritivas

# %%
# Media Aritmética
df['Idade'].mean()
# Out:
# 18.9

# %%
# Mediana
df['Idade'].median()
# Out:
# 18.0

# %%
# Moda
df['Idade'].mode()
# Out:
# 0    18
# Name: Idade, dtype: int64

# %%
#Variância ou Medida de Disperão. Variância entre os dados
df['Idade'].var()
# Out:
# 4.132653061224489

# %%
# Desvio padrão
df['Idade'].std()
# Out:
# 2.032892781536815

# %% [markdown]
# As idades estão variando em media 2 anos para mais ou para menos

# %%
# Medida Estatística
df['Idade'].describe()
# Out:
# count    50.000000
# mean     18.900000
# std       2.032893
# min      17.000000
# 25%      18.000000
# 50%      18.000000
# 75%      19.000000
# max      25.000000
# Name: Idade, dtype: float64

# %%
# Calcular a contagem de idade por sexo:
df['Sexo'].value_counts()
# Out:
# F    37
# M    13
# Name: Sexo, dtype: int64

# %%
#Imprimir as idades por intervalo
print('De %s até %s anos' %(df.Idade.min(), df.Idade.max()))
# Out:
# De 17 até 25 anos

# %%
#Imprimir o intervalo das alturas:
print('De %s até %s metros de altura' %(df.Alt.min(), df.Alt.max()))
# Out:
# De 1.45 até 1.85 metros de altura

# %%
df['Sexo'].describe()
# Out:
# count     50
# unique     2
# top        F
# freq      37
# Name: Sexo, dtype: object

# %% [markdown]
# # Listando por algumas colunas selecionadas

# %%
df_filtro = df[['Turma', 'Sexo', 'Idade']]

# %%
df_filtro
#df_filtro.value_counts()
# Out:
#    Turma Sexo  Idade
# 0      A    F     17
# 1      A    F     18
# 2      A    M     18
# 3      A    M     25
# 4      A    F     19
# 5      A    M     19
# 6      A    F     20
# 7      A    F     18
# 8      A    F     18
# 9      A    F     17
# 10     A    F     18
# 11     A    F     18
# 12     A    F     21
# 13     A    M     19
# 14     A    F     18
# 15     A    F     19
# 16     A    F     17
# 17     A    M     18
# 18     A    F     20
# 19     A    F     18
# 20     A    F     21
# 21     A    F     18
# 22     A    F     18
# 23     A    F     20
# 24     A    F     20
# 25     A    F     19
# 26     B    F     23
# 27     B    F     18
# 28     B    F     18
# 29     B    F     25
# 30     B    F     18
# 31     B    M     17
# 32     B    F     17
# 33     B    F     17
# 34     B    M     18
# 35     B    F     18
# 36     B    M     17
# 37     B    M     21
# 38     B    F     18
# 39     B    M     18
# 40     B    F     17
# 41     B    F     23
# 42     B    M     24
# 43     B    F     18
# 44     B    F     18
# 45     B    F     19
# 46     B    F     19
# 47     B    F     18
# 48     B    M     17
# 49     B    M     18

# %%
#Lista de determinado número de colunas e de linhas. O primeiro bloco determina o intervalo das linhas e o segundo o das colunas. Neste exemplo: linhas de 0 a 4 e colunas de 1 a 4
df.iloc[0:4, 1: 4] #seleção de intervalos de linhas e colunas
# Out:
#   Turma Sexo  Idade
# 0     A    F     17
# 1     A    F     18
# 2     A    M     18
# 3     A    M     25

# %%
#Filtrando por linhas e nomes das colunas: (loc insere pelo rótulo e iloc pelo índice)
df.loc[0:4, 'Turma':'Idade']
# Out:
#   Turma Sexo  Idade
# 0     A    F     17
# 1     A    F     18
# 2     A    M     18
# 3     A    M     25
# 4     A    F     19

# %%
#Filtrando todas as linhas do dataframe na qual a idade é igual a 17
df[df.Idade==17]
# Out:
#     Id Turma Sexo  Idade   Alt  Peso  Filhos Fuma Toler  Exerc  Cine OpCine  \
# 0    1     A    F     17  1.60  60.5       2  NAO     P      0     1      B
# 9   10     A    F     17  1.64  58.0       2  NAO     M      2     2      M
# 16  17     A    F     17  1.82  66.0       1  NAO     P      3     1      B
# 31  32     B    M     17  1.71  73.0       1  NAO     P      1     1      B
# 32  33     B    F     17  1.65  56.0       3  NAO     M      2     1      B
# 33  34     B    F     17  1.67  58.0       1  NAO     M      4     2      B
# 36  37     B    M     17  1.70  95.0       1  NAO     P     10     2      M
# 40  41     B    F     17  1.70  55.0       1  NAO     I      5     4      B
# 48  49     B    M     17  1.80  71.0       1  NAO     P      7     0      M
#
#     TV OpTV
# 0   16    R
# 9   10    R
# 16  10    N
# 31  20    R
# 32  14    R
# 33  10    R
# 36  12    N
# 40  10    B
# 48  14    R

# %%
#Filtrando pessoas maiores de 17
df[df.Idade > 17]
# Out:
#     Id Turma Sexo  Idade   Alt  Peso  Filhos Fuma Toler  Exerc  Cine OpCine  \
# 1    2     A    F     18  1.69  55.0       1  NAO     M      0     1      B
# 2    3     A    M     18  1.85  72.8       2  NAO     P      5     2      M
# 3    4     A    M     25  1.85  80.9       2  NAO     P      5     2      B
# 4    5     A    F     19  1.58  55.0       1  NAO     M      2     2      B
# 5    6     A    M     19  1.76  60.0       3  NAO     M      2     1      B
# 6    7     A    F     20  1.60  58.0       1  NAO     P      3     1      B
# 7    8     A    F     18  1.64  47.0       1  SIM     I      2     2      M
# 8    9     A    F     18  1.62  57.8       3  NAO     M      3     3      M
# 10  11     A    F     18  1.72  70.0       1  SIM     I     10     2      B
# 11  12     A    F     18  1.66  54.0       3  NAO     M      0     2      B
# 12  13     A    F     21  1.70  58.0       2  NAO     M      6     1      M
# 13  14     A    M     19  1.78  68.5       1  SIM     I      5     1      M
# 14  15     A    F     18  1.65  63.5       1  NAO     I      4     1      B
# 15  16     A    F     19  1.63  47.4       3  NAO     P      0     1      B
# 17  18     A    M     18  1.80  85.2       2  NAO     P      3     4      B
# 18  19     A    F     20  1.60  54.5       1  NAO     P      3     2      B
# 19  20     A    F     18  1.68  52.5       3  NAO     M      7     2      B
# 20  21     A    F     21  1.70  60.0       2  NAO     P      8     2      B
# 21  22     A    F     18  1.65  58.5       1  NAO     M      0     3      B
# 22  23     A    F     18  1.57  49.2       1  SIM     I      5     4      B
# 23  24     A    F     20  1.55  48.0       1  SIM     I      0     1      M
# 24  25     A    F     20  1.69  51.6       2  NAO     P      8     5      M
# 25  26     A    F     19  1.54  57.0       2  NAO     I      6     2      B
# 26  27     B    F     23  1.62  63.0       2  NAO     M      8     2      M
# 27  28     B    F     18  1.62  52.0       1  NAO     P      1     1      M
# 28  29     B    F     18  1.57  49.0       2  NAO     P      3     1      B
# 29  30     B    F     25  1.65  59.0       4  NAO     M      1     2      M
# 30  31     B    F     18  1.61  52.0       1  NAO     P      2     2      M
# 34  35     B    M     18  1.73  87.0       1  NAO     M      7     1      B
# 35  36     B    F     18  1.60  47.0       1  NAO     P      5     1      M
# 37  38     B    M     21  1.85  84.0       1  SIM     I      6     4      B
# 38  39     B    F     18  1.70  60.0       1  NAO     P      5     2      B
# 39  40     B    M     18  1.73  73.0       1  NAO     M      4     1      B
# 41  42     B    F     23  1.45  44.0       2  NAO     M      2     2      B
# 42  43     B    M     24  1.76  75.0       2  NAO     I      7     0      M
# 43  44     B    F     18  1.68  55.0       1  NAO     P      5     1      B
# 44  45     B    F     18  1.55  49.0       1  NAO     M      0     1      M
# 45  46     B    F     19  1.70  50.0       7  NAO     M      0     1      B
# 46  47     B    F     19  1.55  54.5       2  NAO     M      4     3      B
# 47  48     B    F     18  1.60  50.0       1  NAO     P      2     1      B
# 49  50     B    M     18  1.83  86.0       1  NAO     P      7     0      M
#
#     TV OpTV
# 1    7    R
# 2   15    R
# 3   20    R
# 4    5    R
# 5    2    R
# 6    7    R
# 7   10    R
# 8   12    R
# 10   8    N
# 11   0    R
# 12  30    R
# 13   2    N
# 14  10    R
# 15  18    R
# 17  10    R
# 18   5    R
# 19  14    M
# 20   5    R
# 21   5    R
# 22  10    R
# 23  28    R
# 24   4    N
# 25   5    R
# 26   5    R
# 27  10    R
# 28  12    R
# 29   2    R
# 30   6    N
# 34  25    B
# 35  14    R
# 37  10    R
# 38  12    R
# 39   2    R
# 41  25    R
# 42  14    N
# 43   8    R
# 44  10    R
# 45   8    R
# 46   3    R
# 47   5    R
# 49  20    B

# %%
#Filtrando pessoas com idade diferente de 18
df[df.Idade != 18]
# Out:
#     Id Turma Sexo  Idade   Alt  Peso  Filhos Fuma Toler  Exerc  Cine OpCine  \
# 0    1     A    F     17  1.60  60.5       2  NAO     P      0     1      B
# 3    4     A    M     25  1.85  80.9       2  NAO     P      5     2      B
# 4    5     A    F     19  1.58  55.0       1  NAO     M      2     2      B
# 5    6     A    M     19  1.76  60.0       3  NAO     M      2     1      B
# 6    7     A    F     20  1.60  58.0       1  NAO     P      3     1      B
# 9   10     A    F     17  1.64  58.0       2  NAO     M      2     2      M
# 12  13     A    F     21  1.70  58.0       2  NAO     M      6     1      M
# 13  14     A    M     19  1.78  68.5       1  SIM     I      5     1      M
# 15  16     A    F     19  1.63  47.4       3  NAO     P      0     1      B
# 16  17     A    F     17  1.82  66.0       1  NAO     P      3     1      B
# 18  19     A    F     20  1.60  54.5       1  NAO     P      3     2      B
# 20  21     A    F     21  1.70  60.0       2  NAO     P      8     2      B
# 23  24     A    F     20  1.55  48.0       1  SIM     I      0     1      M
# 24  25     A    F     20  1.69  51.6       2  NAO     P      8     5      M
# 25  26     A    F     19  1.54  57.0       2  NAO     I      6     2      B
# 26  27     B    F     23  1.62  63.0       2  NAO     M      8     2      M
# 29  30     B    F     25  1.65  59.0       4  NAO     M      1     2      M
# 31  32     B    M     17  1.71  73.0       1  NAO     P      1     1      B
# 32  33     B    F     17  1.65  56.0       3  NAO     M      2     1      B
# 33  34     B    F     17  1.67  58.0       1  NAO     M      4     2      B
# 36  37     B    M     17  1.70  95.0       1  NAO     P     10     2      M
# 37  38     B    M     21  1.85  84.0       1  SIM     I      6     4      B
# 40  41     B    F     17  1.70  55.0       1  NAO     I      5     4      B
# 41  42     B    F     23  1.45  44.0       2  NAO     M      2     2      B
# 42  43     B    M     24  1.76  75.0       2  NAO     I      7     0      M
# 45  46     B    F     19  1.70  50.0       7  NAO     M      0     1      B
# 46  47     B    F     19  1.55  54.5       2  NAO     M      4     3      B
# 48  49     B    M     17  1.80  71.0       1  NAO     P      7     0      M
#
#     TV OpTV
# 0   16    R
# 3   20    R
# 4    5    R
# 5    2    R
# 6    7    R
# 9   10    R
# 12  30    R
# 13   2    N
# 15  18    R
# 16  10    N
# 18   5    R
# 20   5    R
# 23  28    R
# 24   4    N
# 25   5    R
# 26   5    R
# 29   2    R
# 31  20    R
# 32  14    R
# 33  10    R
# 36  12    N
# 37  10    R
# 40  10    B
# 41  25    R
# 42  14    N
# 45   8    R
# 46   3    R
# 48  14    R

# %%
#Filtrar com mais parâmetros, por intervalo:
df[(df.Idade >=18) & (df.Idade < 20)]
# Out:
#     Id Turma Sexo  Idade   Alt  Peso  Filhos Fuma Toler  Exerc  Cine OpCine  \
# 1    2     A    F     18  1.69  55.0       1  NAO     M      0     1      B
# 2    3     A    M     18  1.85  72.8       2  NAO     P      5     2      M
# 4    5     A    F     19  1.58  55.0       1  NAO     M      2     2      B
# 5    6     A    M     19  1.76  60.0       3  NAO     M      2     1      B
# 7    8     A    F     18  1.64  47.0       1  SIM     I      2     2      M
# 8    9     A    F     18  1.62  57.8       3  NAO     M      3     3      M
# 10  11     A    F     18  1.72  70.0       1  SIM     I     10     2      B
# 11  12     A    F     18  1.66  54.0       3  NAO     M      0     2      B
# 13  14     A    M     19  1.78  68.5       1  SIM     I      5     1      M
# 14  15     A    F     18  1.65  63.5       1  NAO     I      4     1      B
# 15  16     A    F     19  1.63  47.4       3  NAO     P      0     1      B
# 17  18     A    M     18  1.80  85.2       2  NAO     P      3     4      B
# 19  20     A    F     18  1.68  52.5       3  NAO     M      7     2      B
# 21  22     A    F     18  1.65  58.5       1  NAO     M      0     3      B
# 22  23     A    F     18  1.57  49.2       1  SIM     I      5     4      B
# 25  26     A    F     19  1.54  57.0       2  NAO     I      6     2      B
# 27  28     B    F     18  1.62  52.0       1  NAO     P      1     1      M
# 28  29     B    F     18  1.57  49.0       2  NAO     P      3     1      B
# 30  31     B    F     18  1.61  52.0       1  NAO     P      2     2      M
# 34  35     B    M     18  1.73  87.0       1  NAO     M      7     1      B
# 35  36     B    F     18  1.60  47.0       1  NAO     P      5     1      M
# 38  39     B    F     18  1.70  60.0       1  NAO     P      5     2      B
# 39  40     B    M     18  1.73  73.0       1  NAO     M      4     1      B
# 43  44     B    F     18  1.68  55.0       1  NAO     P      5     1      B
# 44  45     B    F     18  1.55  49.0       1  NAO     M      0     1      M
# 45  46     B    F     19  1.70  50.0       7  NAO     M      0     1      B
# 46  47     B    F     19  1.55  54.5       2  NAO     M      4     3      B
# 47  48     B    F     18  1.60  50.0       1  NAO     P      2     1      B
# 49  50     B    M     18  1.83  86.0       1  NAO     P      7     0      M
#
#     TV OpTV
# 1    7    R
# 2   15    R
# 4    5    R
# 5    2    R
# 7   10    R
# 8   12    R
# 10   8    N
# 11   0    R
# 13   2    N
# 14  10    R
# 15  18    R
# 17  10    R
# 19  14    M
# 21   5    R
# 22  10    R
# 25   5    R
# 27  10    R
# 28  12    R
# 30   6    N
# 34  25    B
# 35  14    R
# 38  12    R
# 39   2    R
# 43   8    R
# 44  10    R
# 45   8    R
# 46   3    R
# 47   5    R
# 49  20    B

# %%
#Ordenação pelo Sexo
df.sort_values(by = ['Sexo'])
# Out:
#     Id Turma Sexo  Idade   Alt  Peso  Filhos Fuma Toler  Exerc  Cine OpCine  \
# 0    1     A    F     17  1.60  60.5       2  NAO     P      0     1      B
# 23  24     A    F     20  1.55  48.0       1  SIM     I      0     1      M
# 25  26     A    F     19  1.54  57.0       2  NAO     I      6     2      B
# 26  27     B    F     23  1.62  63.0       2  NAO     M      8     2      M
# 27  28     B    F     18  1.62  52.0       1  NAO     P      1     1      M
# 28  29     B    F     18  1.57  49.0       2  NAO     P      3     1      B
# 29  30     B    F     25  1.65  59.0       4  NAO     M      1     2      M
# 30  31     B    F     18  1.61  52.0       1  NAO     P      2     2      M
# 32  33     B    F     17  1.65  56.0       3  NAO     M      2     1      B
# 22  23     A    F     18  1.57  49.2       1  SIM     I      5     4      B
# 33  34     B    F     17  1.67  58.0       1  NAO     M      4     2      B
# 38  39     B    F     18  1.70  60.0       1  NAO     P      5     2      B
# 40  41     B    F     17  1.70  55.0       1  NAO     I      5     4      B
# 41  42     B    F     23  1.45  44.0       2  NAO     M      2     2      B
# 43  44     B    F     18  1.68  55.0       1  NAO     P      5     1      B
# 44  45     B    F     18  1.55  49.0       1  NAO     M      0     1      M
# 45  46     B    F     19  1.70  50.0       7  NAO     M      0     1      B
# 46  47     B    F     19  1.55  54.5       2  NAO     M      4     3      B
# 47  48     B    F     18  1.60  50.0       1  NAO     P      2     1      B
# 35  36     B    F     18  1.60  47.0       1  NAO     P      5     1      M
# 21  22     A    F     18  1.65  58.5       1  NAO     M      0     3      B
# 24  25     A    F     20  1.69  51.6       2  NAO     P      8     5      M
# 19  20     A    F     18  1.68  52.5       3  NAO     M      7     2      B
# 1    2     A    F     18  1.69  55.0       1  NAO     M      0     1      B
# 4    5     A    F     19  1.58  55.0       1  NAO     M      2     2      B
# 6    7     A    F     20  1.60  58.0       1  NAO     P      3     1      B
# 7    8     A    F     18  1.64  47.0       1  SIM     I      2     2      M
# 8    9     A    F     18  1.62  57.8       3  NAO     M      3     3      M
# 20  21     A    F     21  1.70  60.0       2  NAO     P      8     2      B
# 10  11     A    F     18  1.72  70.0       1  SIM     I     10     2      B
# 11  12     A    F     18  1.66  54.0       3  NAO     M      0     2      B
# 9   10     A    F     17  1.64  58.0       2  NAO     M      2     2      M
# 12  13     A    F     21  1.70  58.0       2  NAO     M      6     1      M
# 18  19     A    F     20  1.60  54.5       1  NAO     P      3     2      B
# 15  16     A    F     19  1.63  47.4       3  NAO     P      0     1      B
# 16  17     A    F     17  1.82  66.0       1  NAO     P      3     1      B
# 14  15     A    F     18  1.65  63.5       1  NAO     I      4     1      B
# 36  37     B    M     17  1.70  95.0       1  NAO     P     10     2      M
# 37  38     B    M     21  1.85  84.0       1  SIM     I      6     4      B
# 34  35     B    M     18  1.73  87.0       1  NAO     M      7     1      B
# 39  40     B    M     18  1.73  73.0       1  NAO     M      4     1      B
# 31  32     B    M     17  1.71  73.0       1  NAO     P      1     1      B
# 17  18     A    M     18  1.80  85.2       2  NAO     P      3     4      B
# 42  43     B    M     24  1.76  75.0       2  NAO     I      7     0      M
# 5    6     A    M     19  1.76  60.0       3  NAO     M      2     1      B
# 48  49     B    M     17  1.80  71.0       1  NAO     P      7     0      M
# 3    4     A    M     25  1.85  80.9       2  NAO     P      5     2      B
# 2    3     A    M     18  1.85  72.8       2  NAO     P      5     2      M
# 13  14     A    M     19  1.78  68.5       1  SIM     I      5     1      M
# 49  50     B    M     18  1.83  86.0       1  NAO     P      7     0      M
#
#     TV OpTV
# 0   16    R
# 23  28    R
# 25   5    R
# 26   5    R
# 27  10    R
# 28  12    R
# 29   2    R
# 30   6    N
# 32  14    R
# 22  10    R
# 33  10    R
# 38  12    R
# 40  10    B
# 41  25    R
# 43   8    R
# 44  10    R
# 45   8    R
# 46   3    R
# 47   5    R
# 35  14    R
# 21   5    R
# 24   4    N
# 19  14    M
# 1    7    R
# 4    5    R
# 6    7    R
# 7   10    R
# 8   12    R
# 20   5    R
# 10   8    N
# 11   0    R
# 9   10    R
# 12  30    R
# 18   5    R
# 15  18    R
# 16  10    N
# 14  10    R
# 36  12    N
# 37  10    R
# 34  25    B
# 39   2    R
# 31  20    R
# 17  10    R
# 42  14    N
# 5    2    R
# 48  14    R
# 3   20    R
# 2   15    R
# 13   2    N
# 49  20    B

# %%
#Ordenação pelo Sexo e Idade
df.sort_values(by = ['Sexo','Idade'])
# Out:
#     Id Turma Sexo  Idade   Alt  Peso  Filhos Fuma Toler  Exerc  Cine OpCine  \
# 0    1     A    F     17  1.60  60.5       2  NAO     P      0     1      B
# 9   10     A    F     17  1.64  58.0       2  NAO     M      2     2      M
# 16  17     A    F     17  1.82  66.0       1  NAO     P      3     1      B
# 32  33     B    F     17  1.65  56.0       3  NAO     M      2     1      B
# 33  34     B    F     17  1.67  58.0       1  NAO     M      4     2      B
# 40  41     B    F     17  1.70  55.0       1  NAO     I      5     4      B
# 1    2     A    F     18  1.69  55.0       1  NAO     M      0     1      B
# 7    8     A    F     18  1.64  47.0       1  SIM     I      2     2      M
# 8    9     A    F     18  1.62  57.8       3  NAO     M      3     3      M
# 10  11     A    F     18  1.72  70.0       1  SIM     I     10     2      B
# 11  12     A    F     18  1.66  54.0       3  NAO     M      0     2      B
# 14  15     A    F     18  1.65  63.5       1  NAO     I      4     1      B
# 19  20     A    F     18  1.68  52.5       3  NAO     M      7     2      B
# 21  22     A    F     18  1.65  58.5       1  NAO     M      0     3      B
# 22  23     A    F     18  1.57  49.2       1  SIM     I      5     4      B
# 27  28     B    F     18  1.62  52.0       1  NAO     P      1     1      M
# 28  29     B    F     18  1.57  49.0       2  NAO     P      3     1      B
# 30  31     B    F     18  1.61  52.0       1  NAO     P      2     2      M
# 35  36     B    F     18  1.60  47.0       1  NAO     P      5     1      M
# 38  39     B    F     18  1.70  60.0       1  NAO     P      5     2      B
# 43  44     B    F     18  1.68  55.0       1  NAO     P      5     1      B
# 44  45     B    F     18  1.55  49.0       1  NAO     M      0     1      M
# 47  48     B    F     18  1.60  50.0       1  NAO     P      2     1      B
# 4    5     A    F     19  1.58  55.0       1  NAO     M      2     2      B
# 15  16     A    F     19  1.63  47.4       3  NAO     P      0     1      B
# 25  26     A    F     19  1.54  57.0       2  NAO     I      6     2      B
# 45  46     B    F     19  1.70  50.0       7  NAO     M      0     1      B
# 46  47     B    F     19  1.55  54.5       2  NAO     M      4     3      B
# 6    7     A    F     20  1.60  58.0       1  NAO     P      3     1      B
# 18  19     A    F     20  1.60  54.5       1  NAO     P      3     2      B
# 23  24     A    F     20  1.55  48.0       1  SIM     I      0     1      M
# 24  25     A    F     20  1.69  51.6       2  NAO     P      8     5      M
# 12  13     A    F     21  1.70  58.0       2  NAO     M      6     1      M
# 20  21     A    F     21  1.70  60.0       2  NAO     P      8     2      B
# 26  27     B    F     23  1.62  63.0       2  NAO     M      8     2      M
# 41  42     B    F     23  1.45  44.0       2  NAO     M      2     2      B
# 29  30     B    F     25  1.65  59.0       4  NAO     M      1     2      M
# 31  32     B    M     17  1.71  73.0       1  NAO     P      1     1      B
# 36  37     B    M     17  1.70  95.0       1  NAO     P     10     2      M
# 48  49     B    M     17  1.80  71.0       1  NAO     P      7     0      M
# 2    3     A    M     18  1.85  72.8       2  NAO     P      5     2      M
# 17  18     A    M     18  1.80  85.2       2  NAO     P      3     4      B
# 34  35     B    M     18  1.73  87.0       1  NAO     M      7     1      B
# 39  40     B    M     18  1.73  73.0       1  NAO     M      4     1      B
# 49  50     B    M     18  1.83  86.0       1  NAO     P      7     0      M
# 5    6     A    M     19  1.76  60.0       3  NAO     M      2     1      B
# 13  14     A    M     19  1.78  68.5       1  SIM     I      5     1      M
# 37  38     B    M     21  1.85  84.0       1  SIM     I      6     4      B
# 42  43     B    M     24  1.76  75.0       2  NAO     I      7     0      M
# 3    4     A    M     25  1.85  80.9       2  NAO     P      5     2      B
#
#     TV OpTV
# 0   16    R
# 9   10    R
# 16  10    N
# 32  14    R
# 33  10    R
# 40  10    B
# 1    7    R
# 7   10    R
# 8   12    R
# 10   8    N
# 11   0    R
# 14  10    R
# 19  14    M
# 21   5    R
# 22  10    R
# 27  10    R
# 28  12    R
# 30   6    N
# 35  14    R
# 38  12    R
# 43   8    R
# 44  10    R
# 47   5    R
# 4    5    R
# 15  18    R
# 25   5    R
# 45   8    R
# 46   3    R
# 6    7    R
# 18   5    R
# 23  28    R
# 24   4    N
# 12  30    R
# 20   5    R
# 26   5    R
# 41  25    R
# 29   2    R
# 31  20    R
# 36  12    N
# 48  14    R
# 2   15    R
# 17  10    R
# 34  25    B
# 39   2    R
# 49  20    B
# 5    2    R
# 13   2    N
# 37  10    R
# 42  14    N
# 3   20    R

# %%
#Ordenação pela Ordem Decrescente
df.sort_values(by = ['Idade'], ascending = False)
# Out:
#     Id Turma Sexo  Idade   Alt  Peso  Filhos Fuma Toler  Exerc  Cine OpCine  \
# 29  30     B    F     25  1.65  59.0       4  NAO     M      1     2      M
# 3    4     A    M     25  1.85  80.9       2  NAO     P      5     2      B
# 42  43     B    M     24  1.76  75.0       2  NAO     I      7     0      M
# 26  27     B    F     23  1.62  63.0       2  NAO     M      8     2      M
# 41  42     B    F     23  1.45  44.0       2  NAO     M      2     2      B
# 20  21     A    F     21  1.70  60.0       2  NAO     P      8     2      B
# 37  38     B    M     21  1.85  84.0       1  SIM     I      6     4      B
# 12  13     A    F     21  1.70  58.0       2  NAO     M      6     1      M
# 24  25     A    F     20  1.69  51.6       2  NAO     P      8     5      M
# 23  24     A    F     20  1.55  48.0       1  SIM     I      0     1      M
# 18  19     A    F     20  1.60  54.5       1  NAO     P      3     2      B
# 6    7     A    F     20  1.60  58.0       1  NAO     P      3     1      B
# 5    6     A    M     19  1.76  60.0       3  NAO     M      2     1      B
# 15  16     A    F     19  1.63  47.4       3  NAO     P      0     1      B
# 25  26     A    F     19  1.54  57.0       2  NAO     I      6     2      B
# 13  14     A    M     19  1.78  68.5       1  SIM     I      5     1      M
# 4    5     A    F     19  1.58  55.0       1  NAO     M      2     2      B
# 45  46     B    F     19  1.70  50.0       7  NAO     M      0     1      B
# 46  47     B    F     19  1.55  54.5       2  NAO     M      4     3      B
# 28  29     B    F     18  1.57  49.0       2  NAO     P      3     1      B
# 38  39     B    F     18  1.70  60.0       1  NAO     P      5     2      B
# 43  44     B    F     18  1.68  55.0       1  NAO     P      5     1      B
# 44  45     B    F     18  1.55  49.0       1  NAO     M      0     1      M
# 35  36     B    F     18  1.60  47.0       1  NAO     P      5     1      M
# 34  35     B    M     18  1.73  87.0       1  NAO     M      7     1      B
# 30  31     B    F     18  1.61  52.0       1  NAO     P      2     2      M
# 47  48     B    F     18  1.60  50.0       1  NAO     P      2     1      B
# 39  40     B    M     18  1.73  73.0       1  NAO     M      4     1      B
# 49  50     B    M     18  1.83  86.0       1  NAO     P      7     0      M
# 27  28     B    F     18  1.62  52.0       1  NAO     P      1     1      M
# 10  11     A    F     18  1.72  70.0       1  SIM     I     10     2      B
# 2    3     A    M     18  1.85  72.8       2  NAO     P      5     2      M
# 7    8     A    F     18  1.64  47.0       1  SIM     I      2     2      M
# 22  23     A    F     18  1.57  49.2       1  SIM     I      5     4      B
# 21  22     A    F     18  1.65  58.5       1  NAO     M      0     3      B
# 8    9     A    F     18  1.62  57.8       3  NAO     M      3     3      M
# 19  20     A    F     18  1.68  52.5       3  NAO     M      7     2      B
# 17  18     A    M     18  1.80  85.2       2  NAO     P      3     4      B
# 1    2     A    F     18  1.69  55.0       1  NAO     M      0     1      B
# 14  15     A    F     18  1.65  63.5       1  NAO     I      4     1      B
# 11  12     A    F     18  1.66  54.0       3  NAO     M      0     2      B
# 48  49     B    M     17  1.80  71.0       1  NAO     P      7     0      M
# 9   10     A    F     17  1.64  58.0       2  NAO     M      2     2      M
# 16  17     A    F     17  1.82  66.0       1  NAO     P      3     1      B
# 40  41     B    F     17  1.70  55.0       1  NAO     I      5     4      B
# 36  37     B    M     17  1.70  95.0       1  NAO     P     10     2      M
# 33  34     B    F     17  1.67  58.0       1  NAO     M      4     2      B
# 32  33     B    F     17  1.65  56.0       3  NAO     M      2     1      B
# 31  32     B    M     17  1.71  73.0       1  NAO     P      1     1      B
# 0    1     A    F     17  1.60  60.5       2  NAO     P      0     1      B
#
#     TV OpTV
# 29   2    R
# 3   20    R
# 42  14    N
# 26   5    R
# 41  25    R
# 20   5    R
# 37  10    R
# 12  30    R
# 24   4    N
# 23  28    R
# 18   5    R
# 6    7    R
# 5    2    R
# 15  18    R
# 25   5    R
# 13   2    N
# 4    5    R
# 45   8    R
# 46   3    R
# 28  12    R
# 38  12    R
# 43   8    R
# 44  10    R
# 35  14    R
# 34  25    B
# 30   6    N
# 47   5    R
# 39   2    R
# 49  20    B
# 27  10    R
# 10   8    N
# 2   15    R
# 7   10    R
# 22  10    R
# 21   5    R
# 8   12    R
# 19  14    M
# 17  10    R
# 1    7    R
# 14  10    R
# 11   0    R
# 48  14    R
# 9   10    R
# 16  10    N
# 40  10    B
# 36  12    N
# 33  10    R
# 32  14    R
# 31  20    R
# 0   16    R

# %%
#Tabela de Frequência
df['Sexo'].value_counts() #Contagem das ocorrências de cada valor possível da coluna, ou seja, a frequÊncia
# Out:
# F    37
# M    13
# Name: Sexo, dtype: int64

# %%
#FrequÊncias Relativas
(df['Sexo'].value_counts())/(df['Sexo'].count())
# Out:
# F    0.74
# M    0.26
# Name: Sexo, dtype: float64

# %%
#Tabulação cruzada função do pandas chamada crosstab: quantos alunos de cada sexo tem em cada turma?

pd.crosstab(df['Turma'], df['Sexo'])
# Out:
# Sexo    F  M
# Turma
# A      21  5
# B      16  8

# %% [markdown]
# # Plotando Gráficos

# %%
# vamos plotar
sexo_freq = df['Sexo'].value_counts()
sexo_freq.plot(kind='barh', title='Frequências para os sexos')
plt.show()

# %%
#Gráfico com tabelas cruzadas
#pd.crosstab(df['Sexo'], df['Turma'])

crosstab_sexo_turma = pd.crosstab(df['Sexo'], df['Turma'])
crosstab_sexo_turma.plot(kind = 'bar', stacked=True)
plt.show()

# %% [markdown]
# # Com base nos dados acima, você deverá emitir um parecer, um relatório sobre o que os dados do dataframe representam. Use como base a análise realizada em sala de aula.
